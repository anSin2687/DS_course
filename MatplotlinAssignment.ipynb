# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv('customers.csv')
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
#ANS1 -- OPTION D
#ANS2 -- OPTION D
#ANS3 -- OPTION C
#ANS4 -- OPTION D
#ANS5 -- OPTION A
#ANS6 -- OPTION C
#ANS7 -- OPTION A & C
plt.scatter(df['Gender'],df['Annual Income (k$)'])

# %%
#ANS8 -- OPTION A

data=pd.read_csv('housing.csv')
data.box('bedrooms','grade')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\anups\Documents\MatplotlinAssignment.ipynb Cell 3' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/anups/Documents/MatplotlinAssignment.ipynb#ch0000002?line=0'>1</a> #ANS8 -- OPTION
#       <a href='vscode-notebook-cell:/c%3A/Users/anups/Documents/MatplotlinAssignment.ipynb#ch0000002?line=2'>3</a> data=pd.read_csv('housing.csv')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/anups/Documents/MatplotlinAssignment.ipynb#ch0000002?line=3'>4</a> data.box('bedrooms','grade')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    <a href='file:///c%3A/Users/anups/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=5567'>5568</a> if (
# ...

# %%
#ANS9 -- OPTION A
plt.pie(df['Annual Income (k$)'])
plt.show()

# %%
#ANS10 -- OPTION A
sns.violinplot(data=data, y = 'price',x = 'waterfront')
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
'''ANS11 -- All of the mentioned syntax are incorrect, Option A and C are not know attribute for matplotlib, 
option B requires 3 postional args (x axis,y axis and text ) to work and as well option D requires 1 pos arg to work.'''
# Out:
# 'ANS11 -- All of the mentioned syntax are incorrect, Option A and C are not know attribute for matplotlib, \noption B requires 3 postional args to work and as well option D requires 1 pos arg to work.'

# %%
#ANS12 -- OPTION B
#ANS13 -- OPTION C
#ANS14 -- OPTION A
#ANS15 -- OPTION A
#ANS16 -- OPTION C,4-ALL ARE CORRECT
#ANS17 -- OPTION B
#ANS18 -- OPTION A AND B
#ANS19 -- OPTION C
#ANS20 -- OPTION D
#ANS21 -- OPTION D
